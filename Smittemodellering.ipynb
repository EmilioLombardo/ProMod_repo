# %% [markdown]
# # Smittemodellering

# %%
from pylab import *

data = loadtxt("influensa.txt", skiprows=2, delimiter=",")

obs_tid = data[:,0]
#obs_økninger = data[:,1]
obs_verdier = data[:,1]
#obs_verdier = [sum(obs_økninger[:i]) for i in range(len(obs_økninger))]

plot(obs_tid, obs_verdier)
show()

# %%
I0 = 3
a = 4 / pop # 4 / pop
b = 3.5
pop = 157_759
uker = 48

dt = 0.001

V = 0 # Andel vaksinerte
I = I0 # Smittede
J = I0
S = (pop - I) * (1 - V) # Mottakelige
R = 0 # Restituerte

I_list = [I0]
S_list = [S]
R_list = [R]
t_list = [0]
J_list = [0]

for t in arange(1, uker + 1, dt):
    I = I + a * S * I * dt - b * I * dt
    J = a * S * I
    S = S - a * S * I * dt
    R = R + b * I * dt

    R_list.append(R)
    S_list.append(S)
    I_list.append(I)
    t_list.append(t)
    J_list.append(J)

#plot(t_list, I_list, label="I")
#plot(t_list, S_list, label="S")
#plot(t_list, R_list, label="R")
plot(t_list, J_list, label="J")

legend()
show()

plot(obs_tid, obs_verdier, label="observert I")
show()
